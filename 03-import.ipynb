# %%
import datalook

# %%
help (datalook.analyse)
# Out:
# Help on function analyse in module datalook:
#
# analyse(filenames, outfile=None)
#     This plots the mean, max, and min temperature from each data file
#
#     The function first retrives all data files (given in filenames) and plots the max, min and mean graph for the data files

# %%
datalook.analyse('data/weather-02.csv')
